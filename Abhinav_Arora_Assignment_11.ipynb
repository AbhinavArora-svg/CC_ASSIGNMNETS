# %% [markdown]
# ## ABHNAV ARORA
# ## 102316069
# ---

# %% [markdown]
# # Ques 1. Design a Cognitive Assistant for Reading Labels of medicine bottle

# %% [markdown]
# ![Screenshot 2025-05-04 015500.png](<attachment:Screenshot 2025-05-04 015500.png>)

# %% [markdown]
# ![Screenshot 2025-04-29 200429.png](data:image/png;base64,...)

# %% [markdown]
# # Ques 2.Design an Emotion-aware Cognitive Assistant using Facial Expression Detection

# %% [markdown]
# ![Screenshot 2025-04-29 202118.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-29 202218.png](data:image/png;base64,...)
